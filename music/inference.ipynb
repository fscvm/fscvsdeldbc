# %%
import argparse
import json
import math
import numpy as np
from librosa.feature import chroma_stft
import IPython.display as ipd
from tqdm import tqdm
from scipy.io.wavfile import write

import torch
import torchcrepe

import params
from model import MusicGenerator

import controls

import sys
sys.path.append('hifi-gan/')
from env import AttrDict
from models import Generator as HiFiGAN

import matplotlib.pyplot as plt
# %matplotlib inline

FEAT_STD = 2.39
FEAT_MEAN = -5.38
# Out:
# /home/ma-user/anaconda3/envs/Pytorch-1.0.0/lib/python3.6/site-packages/librosa/core/time_frequency.py:965: RuntimeWarning: divide by zero encountered in log10
#   - 0.5 * np.log10(f_sq + const[3]))
# Number of classifier parameters: 153928
# Number of pitch extractor parameters: 837074

# %%
import librosa
from librosa.core import load
from librosa.filters import mel as librosa_mel_fn

mel_basis = librosa_mel_fn(22050, 1024, 80, 0, 8000)

def get_mel(wav_path):
    wav, _ = load(wav_path, sr=22050)
    wav = wav[:(wav.shape[0] // 256)*256]
    wav = np.pad(wav, 384, mode='reflect')
    stft = librosa.core.stft(wav, n_fft=1024, hop_length=256, win_length=1024, window='hann', center=False)
    stftm = np.sqrt(np.real(stft) ** 2 + np.imag(stft) ** 2 + (1e-9))
    mel_spectrogram = np.matmul(mel_basis, stftm)
    log_mel_spectrogram = np.log(np.clip(mel_spectrogram, a_min=1e-5, a_max=None))
    return log_mel_spectrogram.astype("float32")

# %%
generator = MusicGenerator(params.n_feats, params.n_classes, params.base_dim, params.class_dim,
                           params.beta_min, params.beta_max, FEAT_MEAN, FEAT_STD).cuda()
generator.load_state_dict(torch.load('checkpts/music_generator.pt'))
generator.eval()
print(f'Number of parameters: {generator.nparams}')
# Out:
# Number of parameters: 16940583

# %%
with open('checkpts/hifigan-config.json') as f:
    h = AttrDict(json.load(f))
hifigan = HiFiGAN(h).cuda()
hifigan.load_state_dict(torch.load('checkpts/hifigan-music.pt')['generator'])
hifigan.eval()
hifigan.remove_weight_norm()
# Out:
# Removing weight norm...

# %%
compute_pitch_x = controls.compute_pitch_x
compute_pitch_z = controls.compute_pitch_z
compute_chroma_x = controls.compute_chroma_x
compute_chroma_z = controls.compute_chroma_z
compute_loudness_x = controls.compute_loudness_x
compute_loudness_z = controls.compute_loudness_z
compute_prob_x = controls.compute_prob_x
compute_prob_z = controls.compute_prob_z

def compute_pitch(x):
    return compute_pitch_z(x[:, :params.pitch_mel, :], FEAT_MEAN, FEAT_STD)

def compute_chroma(x):
    return compute_chroma_z(x, FEAT_MEAN, FEAT_STD)

def compute_loudness(x):
    return compute_loudness_z(x, FEAT_MEAN, FEAT_STD)

def compute_prob(x):
    return compute_prob_z(x, FEAT_MEAN, FEAT_STD)

# %%
instrument2id = {'piano': 0, 'flute': 1, 'harpsichord': 2, 'string': 3, 'unknown': -1}
id2instrument = ['piano', 'flute', 'harpsichord', 'string']

weights = dict()
weights['piano'] = {'flute': [0.0, 0.25, 0.05, 0.05], 
                    'harpsichord': [0.0, 0.3, 0.05, 0.05], 
                    'string': [0.0, 0.2, 0.03, 0.02]}
weights['flute'] = {'piano': [0.0, 0.25, 0.07, 0.01], 
                    'harpsichord': [0.01, 0.15, 0.1, 0.02], 
                    'string': [0.01, 0.25, 0.1, 0.05]}
weights['harpsichord'] = {'piano': [0.0, 0.25, 0.07, 0.05], 
                          'flute': [0.01, 0.25, 0.07, 0.1], 
                          'string': [0.0, 0.3, 0.05, 0.1]}
weights['string'] = {'piano': [0.0, 0.25, 0.1, 0.01], 
                     'flute': [0.0, 0.25, 0.04, 0.1], 
                     'harpsichord': [0.0, 0.25, 0.1, 0.1]}
weights['unknown'] = {'piano': [0.0, 0.25, 0.05, 0.05], 
                      'flute': [0.0, 0.25, 0.05, 0.05], 
                      'harpsichord': [0.0, 0.25, 0.05, 0.05], 
                      'string': [0.0, 0.25, 0.05, 0.05]}

# %%
#piano/0sDleZkIK-w_116
#flute/6GwfuWhOOdY_37
#harpsichord/5B4eEcvBIek_114
#string/npQJP_nF7NI_125

# performing timbre transfer
source_id = 'piano/0sDleZkIK-w_116'           # path to source musical excerpt
target_name = 'flute'                         # target musical instrument
n_timesteps = 200                             # number of steps for both reverse and (in case of OT sampling mode) forward diffusion
use_ot = True                                 # whether to use ot samling mode or not
use_control = True                            # whether to use gradient guidance (controlled sampling) or not

source_name = source_id.split('/')[0]
c_source_id = instrument2id[source_name]
c_target_id = instrument2id[target_name]
control_weights = weights[source_name][target_name]
print('Conversion: %s -> %s' % (source_name, target_name))
print('control weights are', control_weights)

source_mel = get_mel('examples/%s.wav' % source_id)
source_mel = source_mel[:, :4*(source_mel.shape[1]//4)]
x_source = torch.from_numpy(source_mel).float().cuda().unsqueeze(0)
lengths_source = torch.LongTensor([x_source.shape[-1]]).cuda()
c_source = torch.LongTensor([c_source_id]).cuda()
c_target = torch.LongTensor([c_target_id]).cuda()

pitch_value = compute_pitch_x(x_source[:, :params.pitch_mel, :]).detach()
chroma_value = compute_chroma_x(x_source).detach()
loudness_value = compute_loudness_x(x_source).detach()

if use_control:
    x_converted = generator.convert(x_source, lengths_source, c_source, c_target, 
                                    compute_pitch, compute_chroma, compute_loudness, compute_prob, 
                                    pitch_value, chroma_value, loudness_value, 
                                    pitch_weight=control_weights[0], chroma_weight=control_weights[1], 
                                    loudness_weight=control_weights[2], clf_weight=control_weights[3], 
                                    use_ot=use_ot, n_timesteps=n_timesteps)
else:
    x_converted = generator.convert(x_source, lengths_source, c_source, c_target, 
                                    compute_pitch, compute_chroma, compute_loudness, compute_prob, 
                                    pitch_value, chroma_value, loudness_value, 
                                    pitch_weight=0.0, chroma_weight=0.0, 
                                    loudness_weight=0.0, clf_weight=0.0, 
                                    use_ot=use_ot, n_timesteps=n_timesteps)
# Out:
# Conversion: piano -> flute
# control weights are [0.0, 0.25, 0.05, 0.05]
#
# Initial MSE in pitch = 0.3541
# Initial MSE in chroma = 0.0914
# Initial MSE in loudness = 43.0007
# Initial min probability = 0.06%
#
# t = 0.950
# MSE in pitch = 0.1034
# MSE in chroma = 0.0924
# MSE in loudness = 17.5978
# Min probability = 0.00%
#
# t = 0.945
# MSE in pitch = 0.1123
# MSE in chroma = 0.0903
# MSE in loudness = 17.0347
# Min probability = 0.01%
#
# t = 0.941
# MSE in pitch = 0.1164
# MSE in chroma = 0.0906
# MSE in loudness = 20.5103
# Min probability = 0.46%
#
# t = 0.936
# MSE in pitch = 0.1248
# MSE in chroma = 0.0881
# MSE in loudness = 20.8065
# Min probability = 1.19%
#
# t = 0.931
# MSE in pitch = 0.1335
# MSE in chroma = 0.0839
# MSE in loudness = 19.3368
# Min probability = 0.28%
#
# t = 0.926
# MSE in pitch = 0.1366
# MSE in chroma = 0.0790
# MSE in loudness = 17.4297
# Min probability = 0.38%
#
# t = 0.921
# MSE in pitch = 0.1410
# MSE in chroma = 0.0776
# MSE in loudness = 20.3655
# Min probability = 0.09%
#
# t = 0.917
# MSE in pitch = 0.1571
# MSE in chroma = 0.0743
# MSE in loudness = 18.3789
# Min probability = 3.91%
#
# t = 0.912
# MSE in pitch = 0.1779
# MSE in chroma = 0.0700
# MSE in loudness = 15.5227
# Min probability = 0.05%
#
# t = 0.907
# MSE in pitch = 0.1972
# MSE in chroma = 0.0650
# MSE in loudness = 12.7146
# Min probability = 0.03%
#
# t = 0.902
# MSE in pitch = 0.2182
# MSE in chroma = 0.0630
# MSE in loudness = 13.3572
# Min probability = 0.22%
#
# t = 0.898
# MSE in pitch = 0.2417
# MSE in chroma = 0.0597
# MSE in loudness = 11.7566
# Min probability = 9.64%
#
# t = 0.893
# MSE in pitch = 0.2664
# MSE in chroma = 0.0572
# MSE in loudness = 10.3936
# Min probability = 0.59%
#
# t = 0.888
# MSE in pitch = 0.2955
# MSE in chroma = 0.0554
# MSE in loudness = 9.1354
# Min probability = 3.23%
#
# t = 0.883
# MSE in pitch = 0.3031
# MSE in chroma = 0.0552
# MSE in loudness = 10.0778
# Min probability = 16.74%
#
# t = 0.879
# MSE in pitch = 0.3220
# MSE in chroma = 0.0546
# MSE in loudness = 9.1868
# Min probability = 19.21%
#
# t = 0.874
# MSE in pitch = 0.3356
# MSE in chroma = 0.0534
# MSE in loudness = 8.6380
# Min probability = 8.50%
#
# t = 0.869
# MSE in pitch = 0.3424
# MSE in chroma = 0.0522
# MSE in loudness = 7.9708
# Min probability = 2.79%
#
# t = 0.864
# MSE in pitch = 0.3697
# MSE in chroma = 0.0513
# MSE in loudness = 6.5917
# Min probability = 15.34%
#
# t = 0.860
# MSE in pitch = 0.3748
# MSE in chroma = 0.0510
# MSE in loudness = 7.0146
# Min probability = 41.33%
#
# t = 0.855
# MSE in pitch = 0.3867
# MSE in chroma = 0.0495
# MSE in loudness = 6.4426
# Min probability = 3.24%
#
# t = 0.850
# MSE in pitch = 0.4074
# MSE in chroma = 0.0480
# MSE in loudness = 5.8217
# Min probability = 5.64%
#
# t = 0.845
# MSE in pitch = 0.4196
# MSE in chroma = 0.0466
# MSE in loudness = 5.6218
# Min probability = 12.21%
#
# t = 0.841
# MSE in pitch = 0.4337
# MSE in chroma = 0.0452
# MSE in loudness = 5.3623
# Min probability = 44.26%
#
# t = 0.836
# MSE in pitch = 0.4550
# MSE in chroma = 0.0425
# MSE in loudness = 5.2562
# Min probability = 13.02%
#
# t = 0.831
# MSE in pitch = 0.4549
# MSE in chroma = 0.0398
# MSE in loudness = 5.5112
# Min probability = 19.27%
#
# t = 0.827
# MSE in pitch = 0.4788
# MSE in chroma = 0.0395
# MSE in loudness = 4.9822
# Min probability = 1.11%
#
# t = 0.822
# MSE in pitch = 0.4991
# MSE in chroma = 0.0368
# MSE in loudness = 4.5072
# Min probability = 51.14%
#
# t = 0.817
# MSE in pitch = 0.5172
# MSE in chroma = 0.0344
# MSE in loudness = 3.8583
# Min probability = 1.56%
#
# t = 0.812
# MSE in pitch = 0.5300
# MSE in chroma = 0.0325
# MSE in loudness = 3.4391
# Min probability = 45.06%
#
# t = 0.807
# MSE in pitch = 0.5436
# MSE in chroma = 0.0315
# MSE in loudness = 3.1124
# Min probability = 24.06%
#
# t = 0.803
# MSE in pitch = 0.5557
# MSE in chroma = 0.0311
# MSE in loudness = 2.9426
# Min probability = 55.77%
#
# t = 0.798
# MSE in pitch = 0.5715
# MSE in chroma = 0.0299
# MSE in loudness = 2.6436
# Min probability = 5.09%
#
# t = 0.793
# MSE in pitch = 0.5652
# MSE in chroma = 0.0286
# MSE in loudness = 2.5734
# Min probability = 6.49%
#
# t = 0.788
# MSE in pitch = 0.5769
# MSE in chroma = 0.0278
# MSE in loudness = 2.4461
# Min probability = 4.84%
#
# t = 0.784
# MSE in pitch = 0.5772
# MSE in chroma = 0.0269
# MSE in loudness = 2.3958
# Min probability = 53.60%
#
# t = 0.779
# MSE in pitch = 0.5788
# MSE in chroma = 0.0252
# MSE in loudness = 2.2821
# Min probability = 0.52%
#
# t = 0.774
# MSE in pitch = 0.5756
# MSE in chroma = 0.0241
# MSE in loudness = 2.1656
# Min probability = 9.65%
#
# t = 0.769
# MSE in pitch = 0.5769
# MSE in chroma = 0.0231
# MSE in loudness = 2.0839
# Min probability = 14.33%
#
# t = 0.765
# MSE in pitch = 0.5765
# MSE in chroma = 0.0225
# MSE in loudness = 2.0189
# Min probability = 68.31%
#
# t = 0.760
# MSE in pitch = 0.5739
# MSE in chroma = 0.0221
# MSE in loudness = 1.9746
# Min probability = 22.13%
#
# t = 0.755
# MSE in pitch = 0.5644
# MSE in chroma = 0.0213
# MSE in loudness = 1.8477
# Min probability = 19.04%
#
# t = 0.750
# MSE in pitch = 0.5706
# MSE in chroma = 0.0211
# MSE in loudness = 1.9662
# Min probability = 53.61%
#
# t = 0.746
# MSE in pitch = 0.5655
# MSE in chroma = 0.0207
# MSE in loudness = 1.8593
# Min probability = 92.05%
#
# t = 0.741
# MSE in pitch = 0.5683
# MSE in chroma = 0.0204
# MSE in loudness = 1.9853
# Min probability = 71.15%
#
# t = 0.736
# MSE in pitch = 0.5595
# MSE in chroma = 0.0199
# MSE in loudness = 1.8201
# Min probability = 47.67%
#
# t = 0.731
# MSE in pitch = 0.5518
# MSE in chroma = 0.0194
# MSE in loudness = 1.7686
# Min probability = 74.68%
#
# t = 0.727
# MSE in pitch = 0.5637
# MSE in chroma = 0.0199
# MSE in loudness = 2.0892
# Min probability = 93.69%
#
# t = 0.722
# MSE in pitch = 0.5611
# MSE in chroma = 0.0195
# MSE in loudness = 2.1494
# Min probability = 89.49%
#
# t = 0.717
# MSE in pitch = 0.5449
# MSE in chroma = 0.0185
# MSE in loudness = 1.8101
# Min probability = 91.45%
#
# t = 0.712
# MSE in pitch = 0.5428
# MSE in chroma = 0.0181
# MSE in loudness = 1.8094
# Min probability = 78.71%
#
# t = 0.708
# MSE in pitch = 0.5449
# MSE in chroma = 0.0180
# MSE in loudness = 1.8388
# Min probability = 97.02%
#
# t = 0.703
# MSE in pitch = 0.5456
# MSE in chroma = 0.0175
# MSE in loudness = 1.8745
# Min probability = 95.36%
#
# t = 0.698
# MSE in pitch = 0.5492
# MSE in chroma = 0.0171
# MSE in loudness = 1.9011
# Min probability = 96.49%
#
# t = 0.694
# MSE in pitch = 0.5445
# MSE in chroma = 0.0166
# MSE in loudness = 1.7761
# Min probability = 89.65%
#
# t = 0.689
# MSE in pitch = 0.5548
# MSE in chroma = 0.0168
# MSE in loudness = 2.0977
# Min probability = 98.28%
#
# t = 0.684
# MSE in pitch = 0.5535
# MSE in chroma = 0.0162
# MSE in loudness = 2.0984
# Min probability = 93.70%
#
# t = 0.679
# MSE in pitch = 0.5459
# MSE in chroma = 0.0155
# MSE in loudness = 1.7943
# Min probability = 88.84%
#
# t = 0.674
# MSE in pitch = 0.5512
# MSE in chroma = 0.0155
# MSE in loudness = 2.0659
# Min probability = 84.07%
#
# t = 0.670
# MSE in pitch = 0.5526
# MSE in chroma = 0.0152
# MSE in loudness = 2.1133
# Min probability = 97.64%
#
# t = 0.665
# MSE in pitch = 0.5522
# MSE in chroma = 0.0150
# MSE in loudness = 2.1319
# Min probability = 98.03%
#
# t = 0.660
# MSE in pitch = 0.5526
# MSE in chroma = 0.0147
# MSE in loudness = 2.1788
# Min probability = 98.63%
#
# t = 0.655
# MSE in pitch = 0.5512
# MSE in chroma = 0.0143
# MSE in loudness = 2.1242
# Min probability = 93.22%
#
# t = 0.651
# MSE in pitch = 0.5564
# MSE in chroma = 0.0143
# MSE in loudness = 2.4038
# Min probability = 98.29%
#
# t = 0.646
# MSE in pitch = 0.5605
# MSE in chroma = 0.0143
# MSE in loudness = 2.7742
# Min probability = 81.99%
#
# t = 0.641
# MSE in pitch = 0.5614
# MSE in chroma = 0.0142
# MSE in loudness = 2.9125
# Min probability = 95.14%
#
# t = 0.636
# MSE in pitch = 0.5638
# MSE in chroma = 0.0142
# MSE in loudness = 3.2069
# Min probability = 97.81%
#
# t = 0.632
# MSE in pitch = 0.5647
# MSE in chroma = 0.0141
# MSE in loudness = 3.3118
# Min probability = 96.78%
#
# t = 0.627
# MSE in pitch = 0.5637
# MSE in chroma = 0.0139
# MSE in loudness = 3.4319
# Min probability = 91.84%
#
# t = 0.622
# MSE in pitch = 0.5640
# MSE in chroma = 0.0137
# MSE in loudness = 3.6507
# Min probability = 83.98%
#
# t = 0.617
# MSE in pitch = 0.5623
# MSE in chroma = 0.0134
# MSE in loudness = 3.7203
# Min probability = 95.83%
#
# t = 0.613
# MSE in pitch = 0.5627
# MSE in chroma = 0.0134
# MSE in loudness = 3.8667
# Min probability = 98.33%
#
# t = 0.608
# MSE in pitch = 0.5601
# MSE in chroma = 0.0130
# MSE in loudness = 3.8775
# Min probability = 97.96%
#
# t = 0.603
# MSE in pitch = 0.5572
# MSE in chroma = 0.0128
# MSE in loudness = 3.9688
# Min probability = 85.52%
#
# t = 0.599
# MSE in pitch = 0.5545
# MSE in chroma = 0.0125
# MSE in loudness = 3.9953
# Min probability = 97.14%
#
# t = 0.594
# MSE in pitch = 0.5546
# MSE in chroma = 0.0123
# MSE in loudness = 4.0725
# Min probability = 99.39%
#
# t = 0.589
# MSE in pitch = 0.5518
# MSE in chroma = 0.0120
# MSE in loudness = 4.0876
# Min probability = 89.99%
#
# t = 0.584
# MSE in pitch = 0.5491
# MSE in chroma = 0.0117
# MSE in loudness = 4.1456
# Min probability = 95.71%
#
# t = 0.579
# MSE in pitch = 0.5469
# MSE in chroma = 0.0117
# MSE in loudness = 4.3949
# Min probability = 89.98%
#
# t = 0.575
# MSE in pitch = 0.5465
# MSE in chroma = 0.0115
# MSE in loudness = 4.4105
# Min probability = 98.89%
#
# t = 0.570
# MSE in pitch = 0.5449
# MSE in chroma = 0.0110
# MSE in loudness = 4.3292
# Min probability = 99.05%
#
# t = 0.565
# MSE in pitch = 0.5414
# MSE in chroma = 0.0107
# MSE in loudness = 4.2701
# Min probability = 96.60%
#
# t = 0.560
# MSE in pitch = 0.5390
# MSE in chroma = 0.0103
# MSE in loudness = 4.2068
# Min probability = 97.18%
#
# t = 0.556
# MSE in pitch = 0.5400
# MSE in chroma = 0.0105
# MSE in loudness = 4.5164
# Min probability = 99.58%
#
# t = 0.551
# MSE in pitch = 0.5371
# MSE in chroma = 0.0100
# MSE in loudness = 4.4448
# Min probability = 99.06%
#
# t = 0.546
# MSE in pitch = 0.5347
# MSE in chroma = 0.0099
# MSE in loudness = 4.5678
# Min probability = 99.53%
#
# t = 0.541
# MSE in pitch = 0.5314
# MSE in chroma = 0.0097
# MSE in loudness = 4.5383
# Min probability = 98.62%
#
# t = 0.537
# MSE in pitch = 0.5314
# MSE in chroma = 0.0097
# MSE in loudness = 4.8240
# Min probability = 99.18%
#
# t = 0.532
# MSE in pitch = 0.5290
# MSE in chroma = 0.0092
# MSE in loudness = 4.6493
# Min probability = 96.48%
#
# t = 0.527
# MSE in pitch = 0.5264
# MSE in chroma = 0.0092
# MSE in loudness = 4.7131
# Min probability = 97.33%
#
# t = 0.522
# MSE in pitch = 0.5246
# MSE in chroma = 0.0090
# MSE in loudness = 4.7451
# Min probability = 97.43%
#
# t = 0.518
# MSE in pitch = 0.5247
# MSE in chroma = 0.0091
# MSE in loudness = 4.9224
# Min probability = 99.50%
#
# t = 0.513
# MSE in pitch = 0.5233
# MSE in chroma = 0.0090
# MSE in loudness = 4.9664
# Min probability = 95.76%
#
# t = 0.508
# MSE in pitch = 0.5207
# MSE in chroma = 0.0086
# MSE in loudness = 4.6180
# Min probability = 99.78%
#
# t = 0.503
# MSE in pitch = 0.5195
# MSE in chroma = 0.0085
# MSE in loudness = 4.5903
# Min probability = 95.68%
#
# t = 0.499
# MSE in pitch = 0.5204
# MSE in chroma = 0.0088
# MSE in loudness = 4.9146
# Min probability = 99.74%
#
# t = 0.494
# MSE in pitch = 0.5189
# MSE in chroma = 0.0084
# MSE in loudness = 4.7654
# Min probability = 89.32%
#
# t = 0.489
# MSE in pitch = 0.5176
# MSE in chroma = 0.0085
# MSE in loudness = 4.8902
# Min probability = 98.54%
#
# t = 0.484
# MSE in pitch = 0.5160
# MSE in chroma = 0.0082
# MSE in loudness = 4.7541
# Min probability = 98.19%
#
# t = 0.480
# MSE in pitch = 0.5165
# MSE in chroma = 0.0087
# MSE in loudness = 5.1011
# Min probability = 99.76%
#
# t = 0.475
# MSE in pitch = 0.5157
# MSE in chroma = 0.0083
# MSE in loudness = 4.9820
# Min probability = 98.38%
#
# t = 0.470
# MSE in pitch = 0.5146
# MSE in chroma = 0.0080
# MSE in loudness = 4.9029
# Min probability = 83.15%
#
# t = 0.465
# MSE in pitch = 0.5132
# MSE in chroma = 0.0079
# MSE in loudness = 4.8790
# Min probability = 92.28%
#
# t = 0.461
# MSE in pitch = 0.5129
# MSE in chroma = 0.0078
# MSE in loudness = 5.0147
# Min probability = 99.93%
#
# t = 0.456
# MSE in pitch = 0.5121
# MSE in chroma = 0.0077
# MSE in loudness = 5.0564
# Min probability = 99.44%
#
# t = 0.451
# MSE in pitch = 0.5113
# MSE in chroma = 0.0075
# MSE in loudness = 5.0299
# Min probability = 98.88%
#
# t = 0.447
# MSE in pitch = 0.5098
# MSE in chroma = 0.0072
# MSE in loudness = 4.8837
# Min probability = 98.58%
#
# t = 0.442
# MSE in pitch = 0.5091
# MSE in chroma = 0.0072
# MSE in loudness = 4.9262
# Min probability = 99.79%
#
# t = 0.437
# MSE in pitch = 0.5087
# MSE in chroma = 0.0070
# MSE in loudness = 4.9155
# Min probability = 99.87%
#
# t = 0.432
# MSE in pitch = 0.5083
# MSE in chroma = 0.0070
# MSE in loudness = 4.9746
# Min probability = 98.85%
#
# t = 0.427
# MSE in pitch = 0.5065
# MSE in chroma = 0.0067
# MSE in loudness = 4.7674
# Min probability = 99.63%
#
# t = 0.423
# MSE in pitch = 0.5070
# MSE in chroma = 0.0069
# MSE in loudness = 4.9739
# Min probability = 99.74%
#
# t = 0.418
# MSE in pitch = 0.5064
# MSE in chroma = 0.0066
# MSE in loudness = 4.8976
# Min probability = 97.17%
#
# t = 0.413
# MSE in pitch = 0.5062
# MSE in chroma = 0.0066
# MSE in loudness = 4.9241
# Min probability = 99.41%
#
# t = 0.408
# MSE in pitch = 0.5049
# MSE in chroma = 0.0065
# MSE in loudness = 4.8164
# Min probability = 99.80%
#
# t = 0.404
# MSE in pitch = 0.5052
# MSE in chroma = 0.0067
# MSE in loudness = 4.9859
# Min probability = 99.79%
#
# t = 0.399
# MSE in pitch = 0.5055
# MSE in chroma = 0.0066
# MSE in loudness = 5.0077
# Min probability = 98.62%
#
# t = 0.394
# MSE in pitch = 0.5054
# MSE in chroma = 0.0064
# MSE in loudness = 4.9912
# Min probability = 99.53%
#
# t = 0.389
# MSE in pitch = 0.5050
# MSE in chroma = 0.0064
# MSE in loudness = 4.9850
# Min probability = 98.48%
#
# t = 0.385
# MSE in pitch = 0.5051
# MSE in chroma = 0.0063
# MSE in loudness = 5.0678
# Min probability = 99.88%
#
# t = 0.380
# MSE in pitch = 0.5048
# MSE in chroma = 0.0061
# MSE in loudness = 5.0374
# Min probability = 99.61%
#
# t = 0.375
# MSE in pitch = 0.5046
# MSE in chroma = 0.0060
# MSE in loudness = 5.0556
# Min probability = 94.48%
#
# t = 0.370
# MSE in pitch = 0.5044
# MSE in chroma = 0.0058
# MSE in loudness = 5.0529
# Min probability = 99.49%
#
# t = 0.366
# MSE in pitch = 0.5044
# MSE in chroma = 0.0059
# MSE in loudness = 5.1723
# Min probability = 99.88%
#
# t = 0.361
# MSE in pitch = 0.5040
# MSE in chroma = 0.0057
# MSE in loudness = 5.1123
# Min probability = 99.86%
#
# t = 0.356
# MSE in pitch = 0.5040
# MSE in chroma = 0.0055
# MSE in loudness = 5.1467
# Min probability = 99.24%
#
# t = 0.351
# MSE in pitch = 0.5034
# MSE in chroma = 0.0054
# MSE in loudness = 5.1066
# Min probability = 99.51%
#
# t = 0.347
# MSE in pitch = 0.5034
# MSE in chroma = 0.0052
# MSE in loudness = 5.1210
# Min probability = 99.86%
#
# t = 0.342
# MSE in pitch = 0.5037
# MSE in chroma = 0.0051
# MSE in loudness = 5.1219
# Min probability = 97.53%
#
# t = 0.337
# MSE in pitch = 0.5040
# MSE in chroma = 0.0050
# MSE in loudness = 5.1728
# Min probability = 88.77%
#
# t = 0.333
# MSE in pitch = 0.5039
# MSE in chroma = 0.0050
# MSE in loudness = 5.2767
# Min probability = 99.55%
#
# t = 0.328
# MSE in pitch = 0.5040
# MSE in chroma = 0.0049
# MSE in loudness = 5.2957
# Min probability = 99.90%
#
# t = 0.323
# MSE in pitch = 0.5042
# MSE in chroma = 0.0048
# MSE in loudness = 5.2915
# Min probability = 99.90%
#
# t = 0.318
# MSE in pitch = 0.5044
# MSE in chroma = 0.0046
# MSE in loudness = 5.3274
# Min probability = 98.54%
#
# t = 0.314
# MSE in pitch = 0.5043
# MSE in chroma = 0.0045
# MSE in loudness = 5.3103
# Min probability = 96.91%
#
# t = 0.309
# MSE in pitch = 0.5046
# MSE in chroma = 0.0045
# MSE in loudness = 5.3411
# Min probability = 99.90%
#
# t = 0.304
# MSE in pitch = 0.5046
# MSE in chroma = 0.0043
# MSE in loudness = 5.2948
# Min probability = 99.81%
#
# t = 0.299
# MSE in pitch = 0.5051
# MSE in chroma = 0.0042
# MSE in loudness = 5.3094
# Min probability = 99.10%
#
# t = 0.294
# MSE in pitch = 0.5050
# MSE in chroma = 0.0042
# MSE in loudness = 5.4341
# Min probability = 98.83%
#
# t = 0.290
# MSE in pitch = 0.5052
# MSE in chroma = 0.0042
# MSE in loudness = 5.5190
# Min probability = 99.90%
#
# t = 0.285
# MSE in pitch = 0.5057
# MSE in chroma = 0.0040
# MSE in loudness = 5.4873
# Min probability = 99.78%
#
# t = 0.280
# MSE in pitch = 0.5055
# MSE in chroma = 0.0039
# MSE in loudness = 5.4469
# Min probability = 98.32%
#
# t = 0.275
# MSE in pitch = 0.5049
# MSE in chroma = 0.0038
# MSE in loudness = 5.3582
# Min probability = 99.85%
#
# t = 0.271
# MSE in pitch = 0.5050
# MSE in chroma = 0.0038
# MSE in loudness = 5.4919
# Min probability = 99.97%
#
# t = 0.266
# MSE in pitch = 0.5047
# MSE in chroma = 0.0037
# MSE in loudness = 5.4052
# Min probability = 98.95%
#
# t = 0.261
# MSE in pitch = 0.5043
# MSE in chroma = 0.0036
# MSE in loudness = 5.3344
# Min probability = 99.85%
#
# t = 0.256
# MSE in pitch = 0.5042
# MSE in chroma = 0.0035
# MSE in loudness = 5.2731
# Min probability = 99.15%
#
# t = 0.252
# MSE in pitch = 0.5037
# MSE in chroma = 0.0035
# MSE in loudness = 5.2410
# Min probability = 99.85%
#
# t = 0.247
# MSE in pitch = 0.5032
# MSE in chroma = 0.0035
# MSE in loudness = 5.1833
# Min probability = 96.40%
#
# t = 0.242
# MSE in pitch = 0.5026
# MSE in chroma = 0.0034
# MSE in loudness = 5.1167
# Min probability = 99.28%
#
# t = 0.237
# MSE in pitch = 0.5017
# MSE in chroma = 0.0033
# MSE in loudness = 5.0333
# Min probability = 96.57%
#
# t = 0.233
# MSE in pitch = 0.5012
# MSE in chroma = 0.0033
# MSE in loudness = 5.0943
# Min probability = 99.92%
#
# t = 0.228
# MSE in pitch = 0.5000
# MSE in chroma = 0.0032
# MSE in loudness = 5.0338
# Min probability = 99.83%
#
# t = 0.223
# MSE in pitch = 0.4989
# MSE in chroma = 0.0031
# MSE in loudness = 4.9879
# Min probability = 98.45%
#
# t = 0.219
# MSE in pitch = 0.4978
# MSE in chroma = 0.0029
# MSE in loudness = 4.8978
# Min probability = 98.92%
#
# t = 0.214
# MSE in pitch = 0.4974
# MSE in chroma = 0.0029
# MSE in loudness = 4.9503
# Min probability = 99.93%
#
# t = 0.209
# MSE in pitch = 0.4962
# MSE in chroma = 0.0028
# MSE in loudness = 4.8768
# Min probability = 98.84%
#
# t = 0.204
# MSE in pitch = 0.4952
# MSE in chroma = 0.0027
# MSE in loudness = 4.7478
# Min probability = 98.40%
#
# t = 0.200
# MSE in pitch = 0.4937
# MSE in chroma = 0.0026
# MSE in loudness = 4.6640
# Min probability = 99.10%
#
# t = 0.195
# MSE in pitch = 0.4933
# MSE in chroma = 0.0026
# MSE in loudness = 4.6817
# Min probability = 99.92%
#
# t = 0.190
# MSE in pitch = 0.4923
# MSE in chroma = 0.0025
# MSE in loudness = 4.5373
# Min probability = 99.82%
#
# t = 0.185
# MSE in pitch = 0.4909
# MSE in chroma = 0.0025
# MSE in loudness = 4.3681
# Min probability = 99.50%
#
# t = 0.180
# MSE in pitch = 0.4903
# MSE in chroma = 0.0024
# MSE in loudness = 4.2640
# Min probability = 99.83%
#
# t = 0.176
# MSE in pitch = 0.4900
# MSE in chroma = 0.0024
# MSE in loudness = 4.3039
# Min probability = 99.96%
#
# t = 0.171
# MSE in pitch = 0.4895
# MSE in chroma = 0.0023
# MSE in loudness = 4.2747
# Min probability = 99.75%
#
# t = 0.166
# MSE in pitch = 0.4886
# MSE in chroma = 0.0023
# MSE in loudness = 4.1036
# Min probability = 99.94%
#
# t = 0.161
# MSE in pitch = 0.4881
# MSE in chroma = 0.0022
# MSE in loudness = 4.0594
# Min probability = 99.92%
#
# t = 0.157
# MSE in pitch = 0.4877
# MSE in chroma = 0.0023
# MSE in loudness = 4.0949
# Min probability = 99.95%
#
# t = 0.152
# MSE in pitch = 0.4869
# MSE in chroma = 0.0022
# MSE in loudness = 3.9871
# Min probability = 99.90%
#
# t = 0.147
# MSE in pitch = 0.4859
# MSE in chroma = 0.0023
# MSE in loudness = 3.9141
# Min probability = 99.14%
#
# t = 0.142
# MSE in pitch = 0.4849
# MSE in chroma = 0.0022
# MSE in loudness = 3.8269
# Min probability = 98.79%
#
# t = 0.138
# MSE in pitch = 0.4843
# MSE in chroma = 0.0020
# MSE in loudness = 3.8407
# Min probability = 99.93%
#
# t = 0.133
# MSE in pitch = 0.4831
# MSE in chroma = 0.0019
# MSE in loudness = 3.7403
# Min probability = 99.74%
#
# t = 0.128
# MSE in pitch = 0.4818
# MSE in chroma = 0.0021
# MSE in loudness = 3.5569
# Min probability = 99.84%
#
# t = 0.123
# MSE in pitch = 0.4805
# MSE in chroma = 0.0019
# MSE in loudness = 3.3951
# Min probability = 99.84%
#
# t = 0.119
# MSE in pitch = 0.4801
# MSE in chroma = 0.0018
# MSE in loudness = 3.4525
# Min probability = 99.97%
#
# t = 0.114
# MSE in pitch = 0.4794
# MSE in chroma = 0.0017
# MSE in loudness = 3.4467
# Min probability = 99.22%
#
# t = 0.109
# MSE in pitch = 0.4789
# MSE in chroma = 0.0018
# MSE in loudness = 3.1721
# Min probability = 98.10%
#
# t = 0.104
# MSE in pitch = 0.4772
# MSE in chroma = 0.0020
# MSE in loudness = 2.9583
# Min probability = 99.82%
#
# t = 0.100
# MSE in pitch = 0.4768
# MSE in chroma = 0.0018
# MSE in loudness = 2.7636
# Min probability = 99.94%
#
# t = 0.095
# MSE in pitch = 0.4759
# MSE in chroma = 0.0015
# MSE in loudness = 2.7366
# Min probability = 99.32%
#
# t = 0.090
# MSE in pitch = 0.4759
# MSE in chroma = 0.0019
# MSE in loudness = 2.5236
# Min probability = 99.73%
#
# t = 0.086
# MSE in pitch = 0.4730
# MSE in chroma = 0.0019
# MSE in loudness = 2.2859
# Min probability = 99.74%
#
# t = 0.081
# MSE in pitch = 0.4730
# MSE in chroma = 0.0015
# MSE in loudness = 2.1885
# Min probability = 99.98%
#
# t = 0.076
# MSE in pitch = 0.4726
# MSE in chroma = 0.0013
# MSE in loudness = 2.2011
# Min probability = 99.76%
#
# t = 0.071
# MSE in pitch = 0.4716
# MSE in chroma = 0.0019
# MSE in loudness = 1.9892
# Min probability = 99.90%
#
# t = 0.067
# MSE in pitch = 0.4714
# MSE in chroma = 0.0019
# MSE in loudness = 2.0668
# Min probability = 99.55%
#
# t = 0.062
# MSE in pitch = 0.4713
# MSE in chroma = 0.0015
# MSE in loudness = 2.0835
# Min probability = 99.97%
#
# t = 0.057
# MSE in pitch = 0.4709
# MSE in chroma = 0.0012
# MSE in loudness = 2.0540
# Min probability = 99.89%
#
# t = 0.052
# MSE in pitch = 0.4702
# MSE in chroma = 0.0030
# MSE in loudness = 1.8126
# Min probability = 99.63%
#
# t = 0.047
# MSE in pitch = 0.4685
# MSE in chroma = 0.0018
# MSE in loudness = 1.6561
# Min probability = 99.67%
#
# t = 0.043
# MSE in pitch = 0.4676
# MSE in chroma = 0.0015
# MSE in loudness = 1.6670
# Min probability = 99.94%
#
# t = 0.038
# MSE in pitch = 0.4671
# MSE in chroma = 0.0014
# MSE in loudness = 1.7058
# Min probability = 98.94%
#
# t = 0.033
# MSE in pitch = 0.4675
# MSE in chroma = 0.0014
# MSE in loudness = 1.6794
# Min probability = 99.74%
# Early stop!
#
# Final MSE in pitch = 0.4675
# Final MSE in chroma = 0.0014
# Final MSE in loudness = 1.6794
# Final min probability = 99.78%

# %%
with torch.no_grad():
    audio_source = hifigan.forward(x_source).cpu().squeeze().clamp(-1, 1)
ipd.display(ipd.Audio(audio_source, rate=22050))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
with torch.no_grad():
    audio_converted = hifigan.forward(x_converted).cpu().squeeze().clamp(-1, 1)
ipd.display(ipd.Audio(audio_converted, rate=22050))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
